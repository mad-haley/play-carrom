# %% [markdown]
# ## Project 01: Mapping Orders!

# %%
# Useful imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.ticker as mtick

# %%
# loading shopify data
shop_orders = pd.read_csv('orders_export_6.11.25.csv')

# %%
shop_orders.head()
# Out:
#    Name                       Email Financial Status  \
# 0  1204    natalieeve11@hotmail.com             paid
# 1  1203                         NaN             paid
# 2  1202         aakash11j@gmail.com             paid
# 3  1201         caltahome@gmail.com             paid
# 4  1200  andreafayjimenez@gmail.com             paid
#
#                      Paid at Fulfillment Status               Fulfilled at  \
# 0  2025-06-09 16:32:24 -0700        unfulfilled                        NaN
# 1  2025-06-09 13:43:56 -0700        unfulfilled                        NaN
# 2  2025-06-09 07:56:24 -0700          fulfilled  2025-06-09 21:00:40 -0700
# 3  2025-06-06 01:40:50 -0700          fulfilled  2025-06-06 11:21:19 -0700
# 4  2025-06-03 09:21:56 -0700          fulfilled  2025-06-03 13:13:21 -0700
#
#   Accepts Marketing Currency  Subtotal  Shipping  ...  Tax 5 Value  \
# 0               yes      USD     125.0     14.99  ...          NaN
# ...

# %%
shop_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         205 non-null    int64
#  1   Email                        194 non-null    object
#  2   Financial Status             204 non-null    object
#  3   Paid at                      188 non-null    object
#  4   Fulfillment Status           204 non-null    object
#  5   Fulfilled at                 201 non-null    object
#  6   Accepts Marketing            204 non-null    object
#  7   Currency                     204 non-null    object
#  8   Subtotal                     204 non-null    float64
#  9   Shipping                     204 non-null    float64
#  10  Taxes                        204 non-null    float64
#  11  Total                        204 non-null    float64
#  12  Discount Code                26 non-null     object
# ...

# %%
# loading tiktok data
tiktok_orders = pd.read_csv('tiktok-orders-2025-06-11.csv')

# %%
tiktok_orders.head()
# Out:
#              Order ID Order Status    Order Substatus  \
# 0  577005674302050400      To ship  Awaiting shipment
# 1  577002680860840813      Shipped         In transit
# 2  576997557003588347      Shipped         In transit
# 3  576994303766270002      Shipped          Delivered
# 4  576993677092295393      Shipped          Delivered
#
#    Cancelation/Return Type Normal or Pre-order               SKU ID  \
# 0                      NaN              Normal  1730510900636128141
# 1                      NaN              Normal  1730510900636128141
# 2                      NaN              Normal  1730510900636128141
# 3                      NaN              Normal  1730510900636128141
# 4                      NaN              Normal  1730510900636128141
#
#    Seller SKU                                       Product Name Variation  \
# 0         NaN  PLAY CARROM Carrom Board with coins, striker, ...   Default
# 1         NaN  PLAY CARROM Carrom Board with coins, striker, ...   Default
# ...

# %%
tiktok_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Order ID                         59 non-null     int64
#  1   Order Status                     59 non-null     object
#  2   Order Substatus                  59 non-null     object
#  3   Cancelation/Return Type          0 non-null      float64
#  4   Normal or Pre-order              59 non-null     object
#  5   SKU ID                           59 non-null     int64
#  6   Seller SKU                       0 non-null      float64
#  7   Product Name                     59 non-null     object
#  8   Variation                        59 non-null     object
#  9   Quantity                         59 non-null     int64
#  10  Sku Quantity of return           59 non-null     int64
#  11  SKU Unit Original Price          59 non-null     int64
# ...

# %%
# merge the 2 datasets (on email col?)

# %%
# make map of orders

# %%
# maybe some other analysis
